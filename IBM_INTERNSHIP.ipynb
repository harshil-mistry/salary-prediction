# %% [markdown]
# <a href="https://colab.research.google.com/github/harshil-mistry/salary-prediction/blob/main/IBM_INTERNSHIP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Docs/adult 3.csv")

# %%
df
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.head()

# %%
df.info()

# %%
df.isnull().sum()

# %%
df.shape

# %%
df.head(15)

# %%
df.head(100)

# %%
df.gender

# %%
df.gender.value_counts()

# %%
for column in df.columns:
  print(column)
  print(len(df[column].value_counts()))
  print()
  print(df[column].value_counts())
  print()

# %%
df['workclass'].replace({'?':'Others'}, inplace=True)
# Out:
# /tmp/ipython-input-9-212529816.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['workclass'].replace({'?':'Others'}, inplace=True)

# %%
df['workclass'].value_counts()
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# Others               2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
df.occupation.replace({'?':'Others'}, inplace=True)
# Out:
# /tmp/ipython-input-11-3767679871.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.occupation.replace({'?':'Others'}, inplace=True)

# %%
df['native-country'].replace({'?':'Others'}, inplace=True)
# Out:
# /tmp/ipython-input-12-3510034042.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['native-country'].replace({'?':'Others'}, inplace=True)

# %%
df.info()

# %%
df.describe()

# %%
df = df[df.workclass != 'Without-pay']
df = df[df.workclass != 'Never-worked']

# %%
df.workclass.value_counts()

# %%
df.shape

# %%
df.isnull().sum()

# %%
df.dropna()
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18        Others  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
df.shape
# Out:
# (48811, 15)

# %%
#Print the income columen where the education is Pre school and 1-4th
df[(df['education'] == '5th-6th')]['income'].value_counts()
# Out:
# income
# <=50K    482
# >50K      27
# Name: count, dtype: int64

# %%
df=df[(df.education != '5th-6th') & (df['education'] != '1st-4th') & (df['education'] != 'Preschool')]

# %%
df.education.value_counts()

# %%
df.shape

# %%
df.education.value_counts()

# %%
df['educational-num'].value_counts()
# Out:
# educational-num
# 9     15768
# 10    10873
# 13     8025
# 14     2657
# 11     2061
# 7      1809
# 12     1599
# 6      1387
# 4       952
# 15      834
# 5       756
# 8       657
# 16      594
# Name: count, dtype: int64

# %%
df.drop(columns=['education'], inplace=True)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'educational-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'income'],
#       dtype='object')

# %%
df.age.value_counts()
# Out:
# age
# 36    1330
# 35    1328
# 33    1312
# 23    1307
# 31    1303
#       ...
# 88       6
# 85       5
# 87       3
# 89       2
# 86       1
# Name: count, Length: 74, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.boxplot(df['age'])
plt.show()

# %%
df = df[(df['age']>18) & (df['age']<70)]

# %%
plt.boxplot(df['age'])
plt.show()

# %%
df.describe()

# %%
plt.boxplot(df['hours-per-week'])
plt.show()

# %%
dict1 = {}
for val, inc in zip(df['native-country'].unique(), range(len(df['native-country'].unique()))):
  dict1[val] = inc
dict1

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'educational-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'income'],
#       dtype='object')

# %%
df.info()

# %%
df['workclass'] = le.fit_transform(df['workclass'])
df['marital-status'] = le.fit_transform(df['marital-status'])
df['occupation'] = le.fit_transform(df['occupation'])
df['relationship'] = le.fit_transform(df['relationship'])
df['race'] = le.fit_transform(df['race'])
df['gender'] = le.fit_transform(df['gender'])
df['native-country'] = le.fit_transform(df['native-country'])

# %%
df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45582 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              45582 non-null  int64
#  1   workclass        45582 non-null  int64
#  2   fnlwgt           45582 non-null  int64
#  3   educational-num  45582 non-null  int64
#  4   marital-status   45582 non-null  int64
#  5   occupation       45582 non-null  int64
#  6   relationship     45582 non-null  int64
#  7   race             45582 non-null  int64
#  8   gender           45582 non-null  int64
#  9   capital-gain     45582 non-null  int64
#  10  capital-loss     45582 non-null  int64
#  11  hours-per-week   45582 non-null  int64
#  12  native-country   45582 non-null  int64
#  13  income           45582 non-null  object
# dtypes: int64(13), object(1)
# memory usage: 5.2+ MB

# %%
x = df.drop(columns=['income'])
y = df['income']
x
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          3  226802                7               4           6
# 1       38          3   89814                9               2           4
# 2       28          1  336951               12               2          11
# 3       44          3  160323               10               2           6
# 5       34          3  198693                6               4           7
# ...    ...        ...     ...              ...             ...         ...
# 48837   27          3  257302               12               2          13
# 48838   40          3  154374                9               2           6
# 48839   58          3  151910                9               6           0
# 48840   22          3  201490                9               4           0
# 48841   52          4  287927                9               2           3
#
# ...

# %%
y

# %%
df

# %%
y

# %%
le.inverse_transform(range(14))
# Out:
# array(['Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#        'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#        'France', 'Germany', 'Greece', 'Guatemala', 'Haiti'], dtype=object)

# %%
for column in df.columns:
  if df[column].dtype == 'object':
    print(column)
# Out:
# income

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %%
x
# Out:
# array([[0.12      , 0.5       , 0.14512876, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.38      , 0.5       , 0.05245126, ..., 0.        , 0.5       ,
#         0.95121951],
#        [0.18      , 0.16666667, 0.21964867, ..., 0.        , 0.39795918,
#         0.95121951],
#        ...,
#        [0.78      , 0.5       , 0.09446153, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.06      , 0.5       , 0.12800425, ..., 0.        , 0.19387755,
#         0.95121951],
#        [0.66      , 0.66666667, 0.18648211, ..., 0.        , 0.39795918,
#         0.95121951]])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)
